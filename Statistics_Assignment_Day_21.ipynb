# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Telecommunication Industry Project<br></h3>

# %% [markdown]
# # Introduction
# This Jupyter notebook is part of your learning experience in the study of applied statistics.
#
# You will work with a data set that contains mobile phone prices and their specifications.
#
# **Dataset Columns Information**
#
# PID = a unique identifier for the phone model
#
# Blue = whether the phone has bluetooth support or not
#
# Wi_Fi = whether the phone has wifi support or not
#
# Tch_Scr = whether the phone has touch screen support or not
#
# Ext_Mem = whether the phone has external memory support or not
#
# Px_h = number of pixels in the vertical axis of the phone
#
# Px_w = number of pixels in the horizontal axis of the phone
#
# Scr_h = height of the screen of the phone in centimetres (cm)
#
# Scr_w = width of the screen of the phone in centimetres (cm)
#
# Int_Mem = internal memory of the phone measured in megabytes (MB)
#
# Bty_Pwr = maximum energy stored by the phone's battery measured in
# milli-Ampere-hours (mAh)
#
# PC = resolution of the primary camera measued in megapixels (MP)
#
# FC = resolution of the front camera measued in megapixels (MP)
#
# RAM = random access memory available in the phone measured in gigabytes (GB)
#
# Depth = depth of the mobile phone measured in centimetres (cm)
#
# Weight = weight of the mobile phone measured in grams (g)
#
# Price = selling price of the mobile phone in rupees

# %% [markdown]
# ## Task 1 - Load and study the data

# %% [markdown]
# Import the libraries that will be used in this notebook

# %%
# Load "numpy" and "pandas" for manipulating numbers and data frames
# Load "matplotlib.pyplot" and "seaborn" for data visualisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Load the csv file as pandas dataframe.

# %%
# Read in the "Dataset" file as a Pandas Data Frame
df=pd.read_csv('Mobile_Phones.csv')

# %%
# Take a brief look at the data
df.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500
# 2        8     3300    2      7     400   4898
# 3       32     3000    2      3     300   6900
# 4       16     3000    2      3     210   5600

# %%
# Get the dimensions of the dataframe
df.shape
# Out:
# (50, 17)

# %%
# Get the row names of the dataframe
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# Get the column names of the dataframe
df.columns
# Out:
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='object')

# %%
# Look at basic information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      50 non-null     object
#  1   Blue     50 non-null     object
#  2   Wi_Fi    50 non-null     object
#  3   Tch_Scr  50 non-null     object
#  4   Ext_Mem  50 non-null     object
#  5   Px_h     50 non-null     int64
#  6   Px_w     50 non-null     int64
#  7   Scr_h    50 non-null     int64
#  8   Scr_w    50 non-null     int64
#  9   PC       50 non-null     int64
#  10  FC       50 non-null     int64
#  11  Int_Mem  50 non-null     int64
#  12  Bty_Pwr  50 non-null     int64
#  13  RAM      50 non-null     int64
#  14  Depth    50 non-null     int64
#  15  Weight   50 non-null     int64
#  16  Price    50 non-null     int64
# dtypes: int64(12), object(5)
# memory usage: 6.8+ KB

# %% [markdown]
# Observations:
#
# There are 50 phones in the data set.
#
# There are 17 features in the data set including the "PID" feature which is used as the row index labels.
#
# There are no missing values in the data set.

# %%
df.isnull().sum()
# Out:
# PID        0
# Blue       0
# Wi_Fi      0
# Tch_Scr    0
# Ext_Mem    0
# Px_h       0
# Px_w       0
# Scr_h      0
# Scr_w      0
# PC         0
# FC         0
# Int_Mem    0
# Bty_Pwr    0
# RAM        0
# Depth      0
# Weight     0
# Price      0
# dtype: int64

# %% [markdown]
# <center>Let's try some logical operators to filter the data.<center>

# %% [markdown]
# ![](https://th.bing.com/th/id/R.0592084daa6518e4fae97f47217ec69e?rik=vNqmiaTVSSo54w&riu=http%3a%2f%2f2.bp.blogspot.com%2f-ujABms6N-Cg%2fTyYwShdTjnI%2fAAAAAAAAAAs%2fktPbHdifidc%2fs1600%2fLogical%2bOperators.PNG&ehk=ww1gl1HB2PcZwPQNHWRUvcQ631Q3mzyHSxL9G4zUKT4%3d&risl=&pid=ImgRaw&r=0,width=700,height=400)

# %% [markdown]
# ## Task 2 - Obtain the logical conditions for the features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem"

# %%
# Get the feature names of the dataframe
phone=df.iloc[:,1:5]

# %%
phone.head()
# Out:
#   Blue Wi_Fi Tch_Scr Ext_Mem
# 0  yes   yes      no      no
# 1  yes   yes      no      no
# 2   no   yes      no      no
# 3   no   yes     yes      no
# 4   no   yes     yes      no

# %%
#Let's tackle these features: "Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"#

# %%
# The children want phones that have the following: Bluetooth, WiFi, touch screen and external memory support
# Create a logical condition for this situation and store the logical values as "con1"
A=df['Blue']=True
B=df['Wi_Fi']=True
C=df['Tch_Scr']=True
D=df['Ext_Mem']=True

con1 =(A and B and C and D)

# %%
con1
# Out:
# True

# %% [markdown]
# Observations:
#
# The features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem" are binary in nature.
#
# The children want all these features, so the logical condition "con1" has been obtained accordingly.

# %% [markdown]
# ## Task 3 - Obtain the logical conditions for the features "Px_h" and "Px_w"

# %%
df.head(2)
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500

# %%
# Get the feature names of the dataframe
df.iloc[:,5:7].head()
# Out:
#    Px_h  Px_w
# 0   780   460
# 1   780   560
# 2   840   720
# 3  1280  1120
# 4  1280  1080

# %%
##

# %%
# Let's tackle these features: "Px_h", "Px_w"

# %%
# Create a new feature called "Px" which stores the total resolution of the screen
df['Px'] = df['Px_h'] * df['Px_w']
df['Px'].head()
# Out:
# 0     358800
# 1     436800
# 2     604800
# 3    1433600
# 4    1382400
# Name: Px, dtype: int64

# %%
# Create a histogram of the "Px" feature and also show the mean and the median
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Px',color='orange',edgecolor = 'linen',
             alpha = 0.8, bins ='auto')

plt.title('Histogram of Px')
plt.xlabel('Px')
plt.ylabel('count')
plt.vlines(df['Px'].mean(), ymin = 0, ymax = 30, colors='blue', label='Mean')
plt.vlines(df['Px'].median(), ymin = 0, ymax =30, colors='red', label='Median')
plt.legend()
plt.show()

# %%
# The children want phones that have good screen resolutions
# Consider the phones that have screen resolutions greater than or equal to the median value in the data set
# Create a logical condition for this situation and store the logical values as "con2"
con2=df['Px']>= df['Px'].median()

# %%
con2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25     True
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# Name: Px, dtype: bool

# %% [markdown]
# Observations:
#
# The features "Px_h" and "Px_w" are respectively the number of pixels in the phone screen in the vertical and horizontal axes.
#
# We created a new feature called "Px" which is the product of the features "Px_h" and "Px_w".
#
# The median has been selected as a threshold in this case.
#
# In case it is too strict, we can choose the mean as a threshold.

# %%
df.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price       Px
# 0        8     2800    2      7     320   3297   358800
# 1        8     3000    2      7     280   4500   436800
# 2        8     3300    2      7     400   4898   604800
# 3       32     3000    2      3     300   6900  1433600
# 4       16     3000    2      3     210   5600  1382400

# %% [markdown]
# # Task 4 - Obtain the logical conditions for the features "Scr_h" and "Scr_w"

# %%
# Let's tackle these features: "Scr_h", "Scr_w"

# %%
# Create a new feature called "Scr_d" which stores the length of the diagonal of the screen of the phone
df['Scr_d'] = np.sqrt(df['Scr_h']**2 + df['Scr_w']**2)
df['Scr_d'].head()
# Out:
# 0    3.162278
# 1    2.236068
# 2    2.236068
# 3    5.830952
# 4    5.000000
# Name: Scr_d, dtype: float64

# %%
# Create a histogram of the "Scr_d" feature and also show the quartiles
# Create Quartiles for feature 
q1=df['Scr_d'].quantile(0.25)
q2=df['Scr_d'].quantile(0.50)
q3=df['Scr_d'].quantile(0.75)
#Plot Histogram
sns.histplot(data=df,x='Scr_d',color='orange',edgecolor = 'linen',
             alpha = 0.8, bins ='auto')
# Add the quartiles to the histogram
plt.axvline(q1, color='r', linestyle='--')
plt.axvline(q2, color='g', linestyle='--')
plt.axvline(q3, color='b', linestyle='--')
# show the plot
plt.plot()
# Out:
# []

# %%
# The children want phones that have very good screen sizes
# Consider the phones that have screen sizes greater than or equal to the upper quartile value in the data set
# Create a logical condition for this situation and store the logical values as "con3"
con3=df['Scr_d']>=q3

# %%
con3
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# 32     True
# 33     True
# 34     True
# 35    False
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "Scr_h" and "Scr_w" are respectively the height and the width of the phone screen.
#
# We created a new feature called "Scr_d" which is essentially the length of the screen diagonal.
#
# The upper quartile has been selected as a threshold in this case as the children were very particular on this point.
#
# In case it is too strict, we can choose the mean or the median as a threshold.

# %% [markdown]
# # Task 5 - Obtain the logical conditions for the features "PC" and "FC"

# %%
df.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price       Px     Scr_d
# 0        8     2800    2      7     320   3297   358800  3.162278
# 1        8     3000    2      7     280   4500   436800  2.236068
# 2        8     3300    2      7     400   4898   604800  2.236068
# 3       32     3000    2      3     300   6900  1433600  5.830952
# 4       16     3000    2      3     210   5600  1382400  5.000000

# %%
# Let's tackle these features: "PC", "FC"

# %%
# Create a histogram of the "PC" feature and also show the mean and the median
plt.figure(figsize=(10,4))
sns.histplot(data=df,x='PC',color='yellow',edgecolor = 'linen',
             alpha = 0.8, bins=5)
plt.title('Histplot of PC')
plt.xlabel('PC')
plt.ylabel('count')
plt.vlines(df['PC'].mean(), ymin = 0, ymax=30,colors='blue',label='Mean')
plt.vlines(df['PC'].median(),ymin = 0, ymax=30,colors='red',label='Median')
plt.legend()
plt.plot()
# Out:
# []

# %%
# Create a histogram of the "FC" feature and also show the mean and the median
plt.figure(figsize=(10,4))
sns.histplot(data=df,x='FC',color='yellow',edgecolor = 'linen',
             alpha = 0.8, bins=5)
plt.title('Histplot of PC')
plt.xlabel('FC')
plt.ylabel('count')
plt.vlines(df['FC'].mean(),ymin=0,ymax=30,colors='blue',label='Mean')
plt.vlines(df['FC'].median(),ymin=0,ymax=30,colors='red',label='Median')
plt.legend()
plt.plot()
# Out:
# []

# %%
# The children want phones that have good primary and front camera resolutions
# Consider the phones that have primary and front camera resolutions greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con4"
con4=(df['PC']>= df['PC'].mean()) & (df['FC']>= df['FC'].mean())

# %%
con4
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# 32     True
# 33     True
# 34     True
# 35    False
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "PC" and "FC" are respectively the resolutions of the primary camera and the front camera.
#
# The respective means have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective medians as thresholds.

# %% [markdown]
# # Task 6 - Obtain the logical conditions for the features "Int_Mem", "Bty_Pwr" and "RAM"

# %%
# Let's tackle these features: "Int_Mem", "Bty_Pwr", "RAM"

# %%
# Create a histogram of the "Int_Mem" feature and also show the mean and the median
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Int_Mem',color='black',edgecolor = 'linen',
             alpha = 0.8, bins=5)
plt.title('Histogram of Internal Memory')
plt.xlabel('Interanl Menory')
plt.ylabel('Count')

plt.vlines(df['Int_Mem'].mean(),ymin=0,ymax=40,colors='blue',linestyles='solid',label='Mean')
plt.vlines(df['Int_Mem'].median(),ymin=0,ymax=40,colors='red',linestyles='solid',label='Median')
plt.legend()
plt.plot()
# Out:
# []

# %%
# Create a histogram of the "Bty_Pwr" feature and also show the mean and the median
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Bty_Pwr',color='Purple',edgecolor = 'linen',
             alpha = 0.5, bins=5)
plt.title('Histogram of Battery Power')
plt.xlabel('Battery Power')
plt.ylabel('Count')
plt.vlines(df['Bty_Pwr'].mean(),ymin=0,ymax=15,colors='blue',linestyles='solid',label='Mean')
plt.vlines(df['Bty_Pwr'].median(),ymin=0,ymax=15,colors='red',linestyles='solid',label='Median')
plt.legend()
plt.plot()
# Out:
# []

# %%
# Create a histogram of the "RAM" feature and also show the mean and the median
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='RAM',color='Maroon',edgecolor = 'linen',
             alpha = 0.5, bins=5)
plt.title('Histogram of RAM')
plt.xlabel('RAM')
plt.ylabel('Count')
plt.vlines(df['RAM'].mean(),ymin=0,ymax=20,colors='blue',linestyles='solid',label='Mean')
plt.vlines(df['RAM'].median(),ymin=0,ymax=20,colors='red',linestyles='solid',label='Median')
plt.legend()
plt.plot()
# Out:
# []

# %%
# The children want phones that have good internal memory, battery power and RAM
# Consider the phones that have internal memory, battery power and RAM greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con5"

con5=(df['Int_Mem']>= df['Int_Mem'].mean()) & (df['Bty_Pwr']>= df['Bty_Pwr'].mean()) & (df['RAM']>= df['RAM'].mean())

# %%
con5
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29     True
# 30     True
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44     True
# 45    False
# 46    False
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations
#
# The features "Int_Mem", "Bty_Pwr" and "RAM" are respectively the internal memory, battery power and RAM of the phones.
#
# The respective means have been selected as thresholds in this case.
#
# .In case it is too strict, we can choose the respective medians as thresholds

# %% [markdown]
# # Task 7 - Obtain the logical conditions for the features "Depth" and "Weight"

# %%
# Let's tackle these features: "Depth", "Weight"

# %%
# Create a histogram of the "Depth" feature and also show the mean and the median
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Depth',color='Lime',edgecolor = 'linen',
             alpha = 0.5, bins=5)
plt.title('Histogram of Depth')
plt.xlabel('Depth')
plt.ylabel('Count')
plt.vlines(df['Depth'].mean(),ymin=0,ymax=30,colors='blue',linestyles='solid',label='Mean')
plt.vlines(df['Depth'].median(),ymin=0,ymax=30,colors='red',linestyles='solid',label='Median')
plt.legend()
plt.plot()
# Out:
# []

# %%
# Create a histogram of the "Weight" feature and also show the mean and the median
plt.figure(figsize=(12,6))
sns.histplot(data=df,x='Weight',color='Cyan',edgecolor = 'linen',
             alpha = 0.5, bins=5)
plt.title('Histogram of Weight')
plt.xlabel('Weight')
plt.ylabel('Count')
plt.vlines(df['Weight'].mean(),ymin=0,ymax=20,colors='blue',linestyles='solid',label='Mean')
plt.vlines(df['Weight'].median(),ymin=0,ymax=20,colors='red',linestyles='solid',label='Median')
plt.legend()
plt.plot()
# Out:
# []

# %%
# The children want phones that are light weight and slim
# Consider the phones that have depth and weight less than or equal to the respective median values in the data set
# Create a logical condition for this situation and store the logical values as "con6"

con6 =(df['Depth']>= df['Depth'].median()) & (df['Weight']>= df['Weight'].median())

# %%
con6
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37     True
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44     True
# 45     True
# 46     True
# 47    False
# 48    False
# 49    False
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "Depth" and "Weight" are respectively the depth of the phone and the weight of the phone.
#
# The respective medians have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective means as thresholds.

# %% [markdown]
# # Task 8 - Subset the data based on all the logical conditions

# %%
# Subset the dataframe using all the logical conditions that have been stored
# Store the subset of the dataframe as a new dataframe called "df1"
df1=pd.DataFrame({'con1':con1,'con2':con2,'con3':con3,'con4':con4,'con5':con5,'con6':con6})

# %%
# Get the dimensions of the dataframe

df1.shape
# Out:
# (50, 6)

# %%
# Sort the dataframe according to the "Price" feature in ascending order and display it
df.sort_values(by='Price',ascending=True,kind='quicksort')
# Out:
#          PID  Blue  Wi_Fi  Tch_Scr  Ext_Mem  Px_h  Px_w  Scr_h  Scr_w   PC  \
# 0    AAB346A  True   True     True     True   780   460      3      1    2
# 1    AAC347I  True   True     True     True   780   560      2      1    4
# 2    BAB657J  True   True     True     True   840   720      2      1    4
# 5    CCQ674K  True   True     True     True  1280  1080      4      3    6
# 4    CCP761U  True   True     True     True  1280  1080      4      3    6
# 3    BBD456K  True   True     True     True  1280  1120      5      3    6
# 18   PEL111K  True   True     True     True  1980  1760      8      6   12
# 6    CTX123L  True   True     True     True  1390  1080      6      3    8
# 19  PNWD777L  True   True     True     True  2880  2120      4      3   24
# 7    DFR256N  True   True     True     True  2880  2120      8      6   12
# 22   QZR577O  True   True     True     True  1440  1280      4      3    8
# 24   RBZ451D  True   True     True     True  1440  1280      6      4    8
# 23   RAY344W  True   True     True     True  2880  2120     10      8    8
# 17   PDG234M  True   True     True     True  2880  2120      8      6    8
# 21   QWR222Y  True   True     True     True  2580  1980      8      6   64
# 14   NBN329S  True   True     True     True  2380  1820      5      3   16
# 25   SDO555G  True   True     True     True  2580  1980      6      3   64
# 16   PDF768G  True   True     True     True  2580  1980      8      6   64
# 15   NSD450I  True   True     True     True  1980  1760     10      8   16
# 9    ENG897N  True   True     True     True  2580  1980      5      3   64
# 13   NAJ56GL  True   True     True     True  2880  2120      6      5   32
# 20   POP857R  True   True     True     True  1980  1760      4      3   32
# 8    DGS789M  True   True     True     True  2580  1920      6      3   32
# 41   WUV902Y  True   True     True     True  2580  1980      8      6   48
# 12   ETT987D  True   True     True     True  2580  1980      6      5   64
# 30   TVF078Y  True   True     True     True  2580  2120      8      6   64
# 29   SYL888P  True   True     True     True  2580  2120      8      6   64
# 39   VYI666I  True   True     True     True  2440  1980      6      5   32
# 36   UST000T  True   True     True     True  2580  1980     10      8   64
# 40   WER765T  True   True     True     True  2580  1980      5      3   64
# 10   EOP657N  True   True     True     True  2580  1920      6      3   32
# 28   SSD000L  True   True     True     True  2580  2120      8      6   64
# 42   WZB298K  True   True     True     True  2580  1980      8      6   64
# 38   VWV532Y  True   True     True     True  2580  1920      5      3   64
# 26   SET568R  True   True     True     True  1980  1280      5      3    8
# 35   ULI999T  True   True     True     True  2440  2120      5      3   32
# 37   USZ111S  True   True     True     True  2440  1980      5      3   48
# 11   ELS333L  True   True     True     True  2580  1920      8      6   64
# 45   XXV567F  True   True     True     True  2580  1980      8      6   64
# 33   TYU444Q  True   True     True     True  2580  2120      8      6   64
# 31   TYQ109G  True   True     True     True  2580  2120      8      6   32
# 32   TYS938L  True   True     True     True  2580  2120      8      6   64
# 27   SFK567Y  True   True     True     True  2580  2120      8      6   64
# 44   XTL675G  True   True     True     True  2580  1980     10      8   64
# 43   XKL901R  True   True     True     True  2580  1980      8      6   32
# 46   YTR67TY  True   True     True     True  2580  1980      4      3   64
# 34   TYY453J  True   True     True     True  2880  2120      6      3   64
# 47   ZDF789K  True   True     True     True  2880  2520      8      6   64
# 48   ZEO567M  True   True     True     True  2880  2520      8      6  128
# 49   ZZZ909X  True   True     True     True  2880  2520      8      6  128
#
#     FC  Int_Mem  Bty_Pwr  RAM  Depth  Weight   Price       Px      Scr_d
# 0    2        8     2800    2      7     320    3297   358800   3.162278
# 1    2        8     3000    2      7     280    4500   436800   2.236068
# 2    2        8     3300    2      7     400    4898   604800   2.236068
# 5    4        8     2980    2      3     230    4990  1382400   5.000000
# 4    2       16     3000    2      3     210    5600  1382400   5.000000
# 3    2       32     3000    2      3     300    6900  1433600   5.830952
# 18   4        8     4000    4      3     330   11388  3484800  10.000000
# 6    4       32     3000    2      3     100   13400  1501200   6.708204
# 19  12       64     2800    4      3     200   14350  6105600   5.000000
# 7    8       32     3200    2      3      80   15600  6105600  10.000000
# 22   8       64     2800    8      3     170   16999  1843200   5.000000
# 24   4       32     2800    8      3     150   17890  1843200   7.211103
# 23   4       16     4800    8      3     170   18900  6105600  12.806248
# 17   8       64     2800    4      3     250   19806  6105600  10.000000
# 21  32      128     4400    4      3     160   21350  5108400  10.000000
# 14   8        8     2800    4      4      80   21972  4331600   5.830952
# 25  32       64     4500    8      3     210   22000  5108400   6.708204
# 16  32      128     3300    4      3     160   22650  5108400  10.000000
# 15  16      128     3900    6      4     180   23456  3484800  12.806248
# 9   32       64     4380    4      3     150   23456  5108400   5.830952
# 13  16       64     2800    6      4     270   23600  6105600   7.810250
# 20  16       16     2800    4      3     150   24560  3484800   5.000000
# 8   16        8     2800    6      3     120   27688  4953600   6.708204
# 41  16      128     3400    4      3     140   28000  5108400  10.000000
# 12  32       64     4500    6      4     300   28700  5108400   7.810250
# 30  32      512     4860    8      3      90   29999  5469600  10.000000
# 29  16      256     5000    8      3     320   32459  5469600  10.000000
# 39  16       32     3200    4      4     180   33460  4831200   7.810250
# 36  32       32     3000    4      4     240   34589  5108400  12.806248
# 40  32      128     3000    4      4     120   34780  5108400   5.830952
# 10  16      128     2800    4      4     210   35460  4953600   6.708204
# 28  32      512     4200    8      3     270   36555  5469600  10.000000
# 42  32     1024     5600    8      3     160   39000  5108400  10.000000
# 38  32       32     4860    8      4     310   39781  4953600   5.830952
# 26   4      128     4500    8      3     220   41320  2534400   5.830952
# 35  16       64     2800    8      4     210   42000  5172800   5.830952
# 37  32      128     4800    4      4     230   42300  4831200   5.830952
# 11  32        8     4500    8      4     150   43980  4953600  10.000000
# 45  32       64     2300    4      3     250   43990  5108400  10.000000
# 33  32      128     2800    8      3     120   45680  5469600  10.000000
# 31  16      256     3300    8      3     110   45899  5469600  10.000000
# 32  32     1024     4860    8      3     120   46777  5469600  10.000000
# 27  16       32     4300    8      3     200   49899  5469600  10.000000
# 44  32      512     4560    8      3     260   51230  5108400  12.806248
# 43  16      256     3900    4      3     210   54320  5108400  10.000000
# 46  32       64     2800    4      3     200   56000  5108400   5.000000
# 34  32      128     4400    8      4     150   61750  6105600   6.708204
# 47  32      512     5600   12      2      80   84566  7257600  10.000000
# 48  64      512     5600   12      2     110   88999  7257600  10.000000
# 49  64     1024     5600   12      2     130  149000  7257600  10.000000

# %% [markdown]
# Observations:
#
# Based on all the logical conditions obtained through analysis of the features, we are left with three phones.
#
# The most expensive of these phones is the "TYS938L" model and the least expensive is the "TVF078Y" model.
#
# We could let the children choose from these three phones as per their preferences.

# %% [markdown]
# # Task 9 - Study the variability of the features in the original data set

# %%
# Calculate the ratio of the standard deviation to the mean for all the numerical features in the dataframe
# Store these values in a new series wherein the rows are the features and the only column is the calculated ratio
# Name the series as "deviations"
df2=df.select_dtypes(include=['int','float'])
df2.head()
# Out:
#    Px_h  Px_w  Scr_h  Scr_w  PC  FC  Int_Mem  Bty_Pwr  RAM  Depth  Weight  \
# 0   780   460      3      1   2   2        8     2800    2      7     320
# 1   780   560      2      1   4   2        8     3000    2      7     280
# 2   840   720      2      1   4   2        8     3300    2      7     400
# 3  1280  1120      5      3   6   2       32     3000    2      3     300
# 4  1280  1080      4      3   6   2       16     3000    2      3     210
#
#    Price       Px     Scr_d
# 0   3297   358800  3.162278
# 1   4500   436800  2.236068
# 2   4898   604800  2.236068
# 3   6900  1433600  5.830952
# 4   5600  1382400  5.000000

# %%
std_value=df2.std()
mean_value=df2.mean()
ratios = std_value / mean_value

# %%
deviations=pd.Series(ratios,name="deviations")
print(deviations)
# Out:
# Px_h       0.257998
# Px_w       0.256226
# Scr_h      0.314293
# Scr_w      0.407624
# PC         0.715716
# FC         0.712184
# Int_Mem    1.506514
# Bty_Pwr    0.256368
# RAM        0.479075
# Depth      0.306072
# Weight     0.388121
# Price      0.740868
# Px         0.398680
# Scr_d      0.340469
# Name: deviations, dtype: float64

# %%
# View the "deviations" series after sorting it in descending order
deviations.sort_values(ascending=False, kind='quicksort')
# Out:
# Int_Mem    1.506514
# Price      0.740868
# PC         0.715716
# FC         0.712184
# RAM        0.479075
# Scr_w      0.407624
# Px         0.398680
# Weight     0.388121
# Scr_d      0.340469
# Scr_h      0.314293
# Depth      0.306072
# Px_h       0.257998
# Bty_Pwr    0.256368
# Px_w       0.256226
# Name: deviations, dtype: float64

# %% [markdown]
# Observations:
#
# The ratio of the standard deviation to the mean of a feature normalises it in a way.
#
# This allows for comparison between multiple features.
#
# The most variable feature in the original data set is the internal memory of the phones.
#
# The least variable feature in the original data set is the number of screen pixels in the horizontal axis.
#
# Although most features don't seem so variable, the prices of the phones are quite variable.
#
# Feel free to investigate what could be the cause of this difference in variability.
#
# Note: We encourage you to extend this analysis further and see what else you can find.
#
# Note: Please refer to the official website of Python and its libraries for various Python documentations.

# %% [markdown]
# # Conclusion
# 1. We have used concepts of descriptive statistics to study and work with a data set that contains mobile phone specifications.
#
# 2. We were able to recommend three phone models to the client which she can then propose to her children.
